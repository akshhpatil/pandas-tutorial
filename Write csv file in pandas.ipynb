# %% [markdown]
# # Write csv file in pandas

# %%
import pandas as pd

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv')

# %%
data
# Out:
#    age     name  gander
# 0   33   akshay    male
# 1   34   manali  female
# 2   56  yuganat    male
# 3   23     abhi    male
# 4   45   harshi  female

# %%
data.columns
# Out:
# Index(['age', 'name', 'gander'], dtype='object')

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv' ,nrows =3 )     # get 3 rows

# %%
data
# Out:
#    age     name  gander
# 0   33   akshay    male
# 1   34   manali  female
# 2   56  yuganat    male

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv' ,usecols = [0,1] )  #get columns

# %%
data
# Out:
#    age     name
# 0   33   akshay
# 1   34   manali
# 2   56  yuganat
# 3   23     abhi
# 4   45   harshi

# %%
 #skiprows skip the rows skiprows = [0]  you can give index also
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv' ,skiprows = 1)

# %%
data
# Out:
#    33   akshay    male
# 0  34   manali  female
# 1  56  yuganat    male
# 2  23     abhi    male
# 3  45   harshi  female

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv')
data
# Out:
#    age     name  gander
# 0   33   akshay    male
# 1   34   manali  female
# 2   56  yuganat    male
# 3   23     abhi    male
# 4   45   harshi  female

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv', index_col = "age")
data
# Out:
#         name  gander
# age
# 33    akshay    male
# 34    manali  female
# 56   yuganat    male
# 23      abhi    male
# 45    harshi  female

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv')
data
# Out:
#           0        1       2
# 0       age     name  gander
# 1        33   akshay    male
# 2        34   manali  female
# 3        56  yuganat    male
# 4        23     abhi    male
# 5        45   harshi  female

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv' ,header = 1)
data
# Out:
#         age     name  gander
# 0        33   akshay    male
# 1        34   manali  female
# 2        56  yuganat    male
# 3        23     abhi    male
# 4        45   harshi  female

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv' )
data
# Out:
#    33   akshay    male
# 0  34   manali  female
# 1  56  yuganat    male
# 2  23     abhi    male
# 3  45   harshi  female

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv' ,header =None)
data
# Out:
#     0        1       2
# 0  33   akshay    male
# 1  34   manali  female
# 2  56  yuganat    male
# 3  23     abhi    male
# 4  45   harshi  female

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv' ,header =None ,prefix = "columns")

data
# Out:
#    columns0 columns1 columns2
# 0        33   akshay     male
# 1        34   manali   female
# 2        56  yuganat     male
# 3        23     abhi     male
# 4        45   harshi   female

# %%
data =pd.read_csv('C:\\Users\\admin\\Desktop\\book1.csv' ,names = ['age of stud','names of stud','gender of stude'])
data
# Out:
#    age of stud names of stud gender of stude
# 0           33        akshay            male
# 1           34        manali          female
# 2           56       yuganat            male
# 3           23          abhi            male
# 4           45        harshi          female
